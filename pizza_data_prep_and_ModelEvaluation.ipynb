# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pizza_df = pd.read_csv('pizza_sales.csv')
ingred_df = pd.read_csv('Pizza_ingredients.csv')

# %%
pizza_df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1         2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2         3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3         4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4         5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
pizza_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48604 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48613 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48597 non-null  object
#  10  pizza_ingredients  48607 non-null  object
#  11  pizza_name         48613 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
pizza_df.isna().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id        16
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           7
# pizza_size            0
# pizza_category       23
# pizza_ingredients    13
# pizza_name            7
# dtype: int64

# %%
pizza_df.dropna(inplace=True)

# %%
pizza_df.isna().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
pizza_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pizza_df.shape
# Out:
# (48554, 12)

# %%
def parse_dates(date):
  for fmt in ('%d-%m-%Y', '%d/%m/%Y'):
    try:
      return pd.to_datetime(date, format=fmt)
    except ValueError:
      pass
  raise ValueError(f'no valid date format found for {date}')

# %%
pizza_df['order_date'] = pizza_df['order_date'].apply(parse_dates)

# %%
pizza_df['order_date'].head()
# Out:
# 0   2015-01-01
# 1   2015-01-01
# 2   2015-01-01
# 3   2015-01-01
# 4   2015-01-01
# Name: order_date, dtype: datetime64[ns]

# %%
# Group by order date and sum the quantity
quantity_over_time = pizza_df.groupby('order_date')['quantity'].sum()

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(quantity_over_time.index, quantity_over_time.values)
plt.xlabel('Order Date')
plt.ylabel('Quantity Sold')
plt.title('Quantity Sold Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Autocorrelation and partial Autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(quantity_over_time, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(quantity_over_time, lags=40, ax=ax2)

# %% [markdown]
# P = 1
#
# q = 1
#
# d = 0

# %% [markdown]
# Testing for Stationary :

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# H0: it is not stationary
# H1: it is stationary

def adf_test(sales):
  result = adfuller(sales)
  print('ADF Statistic: %f' % result[0])
  print('p-value: %f' % result[1])
  print(f'# Lags used: {result[2]}')
  print(f'No of observations used: {result[3]}')
  if result[1] <= 0.05:
    print('we reject the null hypothesis, The series is stationary')
  else:
    print('Not enough statistical evidence to reject null hypothesis, The series is not stationary')

# %%
adf_test(quantity_over_time)
# Out:
# ADF Statistic: -5.208670
# p-value: 0.000008
# # Lags used: 15
# No of observations used: 342
# we reject the null hypothesis, The series is stationary

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
eval_data = pizza_df.groupby(['order_date', 'pizza_name'])['quantity'].sum().unstack().fillna(0)

# %%
eval_data.head()
# Out:
# pizza_name  The Barbecue Chicken Pizza  The Big Meat Pizza  \
# order_date
# 2015-01-01                        11.0                 5.0
# 2015-01-02                         8.0                 8.0
# 2015-01-03                         7.0                 8.0
# 2015-01-04                         9.0                 0.0
# 2015-01-05                         2.0                 3.0
#
# pizza_name  The Brie Carre Pizza  The Calabrese Pizza  \
# order_date
# 2015-01-01                   0.0                  1.0
# 2015-01-02                   0.0                  0.0
# 2015-01-03                   0.0                  1.0
# 2015-01-04                   2.0                  2.0
# 2015-01-05                   2.0                  0.0
#
# pizza_name  The California Chicken Pizza  The Chicken Alfredo Pizza  \
# order_date
# 2015-01-01                           4.0                        2.0
# 2015-01-02                           5.0                        1.0
# 2015-01-03                          11.0                        5.0
# 2015-01-04                           5.0                        4.0
# 2015-01-05                           6.0                        8.0
#
# pizza_name  The Chicken Pesto Pizza  The Classic Deluxe Pizza  \
# order_date
# 2015-01-01                      4.0                      10.0
# 2015-01-02                      2.0                       6.0
# 2015-01-03                      3.0                       5.0
# 2015-01-04                      1.0                       4.0
# 2015-01-05                      2.0                       9.0
#
# pizza_name  The Five Cheese Pizza  The Four Cheese Pizza  ...  \
# order_date                                                ...
# 2015-01-01                    6.0                    5.0  ...
# 2015-01-02                    6.0                    3.0  ...
# 2015-01-03                    4.0                    7.0  ...
# 2015-01-04                    2.0                    4.0  ...
# 2015-01-05                    5.0                    4.0  ...
#
# pizza_name  The Prosciutto and Arugula Pizza  The Sicilian Pizza  \
# order_date
# 2015-01-01                               4.0                 4.0
# 2015-01-02                               4.0                 6.0
# 2015-01-03                               7.0                 6.0
# 2015-01-04                               4.0                 3.0
# 2015-01-05                               2.0                 5.0
#
# pizza_name  The Soppressata Pizza  The Southwest Chicken Pizza  \
# order_date
# 2015-01-01                    0.0                          7.0
# 2015-01-02                    4.0                          6.0
# 2015-01-03                    1.0                          5.0
# 2015-01-04                    0.0                          1.0
# 2015-01-05                    2.0                          3.0
#
# pizza_name  The Spicy Italian Pizza  The Spinach Pesto Pizza  \
# order_date
# 2015-01-01                      5.0                      2.0
# 2015-01-02                     11.0                      2.0
# 2015-01-03                      4.0                      3.0
# 2015-01-04                      4.0                      3.0
# 2015-01-05                      2.0                      4.0
#
# pizza_name  The Spinach Supreme Pizza  The Spinach and Feta Pizza  \
# order_date
# 2015-01-01                        5.0                         2.0
# 2015-01-02                        7.0                         4.0
# 2015-01-03                        2.0                         2.0
# 2015-01-04                        4.0                         3.0
# 2015-01-05                        2.0                         2.0
#
# pizza_name  The Thai Chicken Pizza  The Vegetables + Vegetables Pizza
# order_date
# 2015-01-01                     7.0                                3.0
# 2015-01-02                     9.0                                5.0
# 2015-01-03                     9.0                                7.0
# 2015-01-04                     5.0                                1.0
# 2015-01-05                     6.0                                2.0
#
# [5 rows x 32 columns]

# %%
one_pizza = eval_data['The Barbecue Chicken Pizza']

# %%
# split train and test
train = one_pizza[:-7]
test = one_pizza[-7:]

# %%
# Fit Arima model
ari_model = ARIMA(train, order=(1, 1, 0))
ari_result = ari_model.fit()
# Out:
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# forecast
ari_forecast = ari_result.get_forecast(steps=len(test))
ari_fore_values = ari_forecast.predicted_mean
# Out:
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
ari_predict = ari_result.predict(start=len(train), end=len(train)+len(test)-1, dynamic=True)
# Out:
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
ari_predict.index = test.index

# %%
# concat test and ari_predict without changing the index of test, test is a pandas series

concatenated_series = pd.concat([test, ari_predict], axis=1)
concatenated_series.columns = ['Actual', 'Predicted']
concatenated_series
# Out:
#             Actual  Predicted
# order_date
# 2015-12-24     4.0   4.970012
# 2015-12-26     5.0   5.500450
# 2015-12-27     4.0   5.227277
# 2015-12-28     2.0   5.367959
# 2015-12-29     4.0   5.295509
# 2015-12-30     6.0   5.332820
# 2015-12-31    10.0   5.313605

# %%
concatenated_series.plot(figsize=(12, 6))
plt.xlabel('Order Date')
plt.ylabel('Quantity Sold')
plt.title('Actual vs. Predicted Quantity Sold for "The Barbecue Chicken Pizza"')
plt.show()

# %%
# Evaluate the model
mae = mean_absolute_error(test, ari_fore_values)
mse = mean_squared_error(test, ari_fore_values)
rmse = np.sqrt(mse)

print(f'ARIMA MAE: {mae}')
print(f'ARIMA MSE: {mse}')
print(f'ARIMA RMSE: {rmse}')
# Out:
# ARIMA MAE: 1.8163972880345898
# ARIMA MSE: 5.446642862241798
# ARIMA RMSE: 2.3338043753155056

# %%
# fit SARIMA model
sari_model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 7))
sari_result = sari_model.fit()
# Out:
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# sarima forecast
sari_forecast = sari_result.get_forecast(steps=len(test))
sari_fore_values = sari_forecast.predicted_mean
# Out:
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Evaluate Sarima
mae = mean_absolute_error(test, sari_fore_values)
mse = mean_squared_error(test, sari_fore_values)
rmse = np.sqrt(mse)

print(f'SARIMAX MAE: {mae}')
print(f'SARIMAX MSE: {mse}')
print(f'SARIMAX RMSE: {rmse}')
# Out:
# SARIMAX MAE: 2.5756161268619104
# SARIMAX MSE: 8.29645933244063
# SARIMAX RMSE: 2.88035750080448

# %%
sari_predict = sari_result.predict(start=len(train), end=len(train)+len(test)-1, dynamic=True)
# Out:
# c:\Users\sivakumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
sari_predict.index = test.index

# %%
sari_predict
# Out:
# order_date
# 2015-12-24    7.277264
# 2015-12-26    7.483852
# 2015-12-27    5.526712
# 2015-12-28    6.339173
# 2015-12-29    6.738250
# 2015-12-30    5.870214
# 2015-12-31    6.465724
# Name: predicted_mean, dtype: float64

# %%
concatenated_sarima = pd.concat([test, sari_predict] , axis=1)
concatenated_sarima.columns = ['Actual', 'Predicted']
concatenated_sarima
# Out:
#             Actual  Predicted
# order_date
# 2015-12-24     4.0   7.277264
# 2015-12-26     5.0   7.483852
# 2015-12-27     4.0   5.526712
# 2015-12-28     2.0   6.339173
# 2015-12-29     4.0   6.738250
# 2015-12-30     6.0   5.870214
# 2015-12-31    10.0   6.465724

# %%
concatenated_sarima.plot(figsize=(12, 6))
plt.xlabel('Order Date')
plt.ylabel('Quantity Sold')
plt.title('Actual vs. Predicted Quantity Sold for "The Barbecue Chicken Pizza"')
plt.show()

# %% [markdown]
# Prophet Evaluation

# %%
pip install prophet
# Out:
# Collecting prophetNote: you may need to restart the kernel to use updated packages.
#
#   Downloading prophet-1.1.6-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.2.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from prophet) (2.1.2)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from prophet) (3.9.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from prophet) (2.2.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.64-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from prophet) (4.67.1)
# Collecting importlib-resources (from prophet)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: colorama in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\sivakumar\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Downloading prophet-1.1.6-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/13.3 MB 1.8 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/13.3 MB 1.4 MB/s eta 0:00:10
#     --------------------------------------- 0.2/13.3 MB 1.2 MB/s eta 0:00:12
#     --------------------------------------- 0.2/13.3 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.3/13.3 MB 1.1 MB/s eta 0:00:13
#     --------------------------------------- 0.3/13.3 MB 1.0 MB/s eta 0:00:13
#    - -------------------------------------- 0.4/13.3 MB 1.1 MB/s eta 0:00:13
#    - -------------------------------------- 0.4/13.3 MB 1.1 MB/s eta 0:00:13
#    - -------------------------------------- 0.4/13.3 MB 1.1 MB/s eta 0:00:13
#    - -------------------------------------- 0.5/13.3 MB 1.0 MB/s eta 0:00:13
#    - -------------------------------------- 0.5/13.3 MB 1.0 MB/s eta 0:00:13
#    - -------------------------------------- 0.6/13.3 MB 1.0 MB/s eta 0:00:13
#    - -------------------------------------- 0.6/13.3 MB 1.1 MB/s eta 0:00:13
#    -- ------------------------------------- 0.7/13.3 MB 1.0 MB/s eta 0:00:13
#    -- ------------------------------------- 0.7/13.3 MB 1.1 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/13.3 MB 1.1 MB/s eta 0:00:12
#    -- ------------------------------------- 0.9/13.3 MB 1.1 MB/s eta 0:00:12
#    -- ------------------------------------- 0.9/13.3 MB 1.1 MB/s eta 0:00:12
#    -- ------------------------------------- 1.0/13.3 MB 1.1 MB/s eta 0:00:12
#    --- ------------------------------------ 1.0/13.3 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.1/13.3 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.2/13.3 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.2/13.3 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.3/13.3 MB 1.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.4/13.3 MB 1.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.4/13.3 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.5/13.3 MB 1.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.6/13.3 MB 1.2 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.6/13.3 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.7/13.3 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/13.3 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.9/13.3 MB 1.3 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.9/13.3 MB 1.3 MB/s eta 0:00:10
#    ------ --------------------------------- 2.0/13.3 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.1/13.3 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.2/13.3 MB 1.3 MB/s eta 0:00:09
#    ------- -------------------------------- 2.3/13.3 MB 1.3 MB/s eta 0:00:09
#    ------- -------------------------------- 2.4/13.3 MB 1.4 MB/s eta 0:00:08
#    ------- -------------------------------- 2.5/13.3 MB 1.4 MB/s eta 0:00:08
#    -------- ------------------------------- 2.7/13.3 MB 1.4 MB/s eta 0:00:08
#    -------- ------------------------------- 2.7/13.3 MB 1.4 MB/s eta 0:00:08
#    -------- ------------------------------- 2.7/13.3 MB 1.4 MB/s eta 0:00:08
#    -------- ------------------------------- 2.7/13.3 MB 1.4 MB/s eta 0:00:08
#    -------- ------------------------------- 2.8/13.3 MB 1.4 MB/s eta 0:00:08
#    -------- ------------------------------- 2.8/13.3 MB 1.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.4/13.3 MB 1.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.5/13.3 MB 1.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.6/13.3 MB 1.6 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.8/13.3 MB 1.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.8/13.3 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 4.0/13.3 MB 1.7 MB/s eta 0:00:06
#    ------------ --------------------------- 4.1/13.3 MB 1.7 MB/s eta 0:00:06
#    ------------ --------------------------- 4.3/13.3 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.4/13.3 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.6/13.3 MB 1.8 MB/s eta 0:00:05
#    ------------- -------------------------- 4.7/13.3 MB 1.8 MB/s eta 0:00:05
#    -------------- ------------------------- 4.9/13.3 MB 1.8 MB/s eta 0:00:05
#    --------------- ------------------------ 5.0/13.3 MB 1.8 MB/s eta 0:00:05
#    --------------- ------------------------ 5.1/13.3 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.4/13.3 MB 1.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.3 MB 1.9 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.7/13.3 MB 1.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.8/13.3 MB 1.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.9/13.3 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 6.2/13.3 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 6.3/13.3 MB 2.0 MB/s eta 0:00:04
#    ------------------- -------------------- 6.5/13.3 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 6.7/13.3 MB 2.1 MB/s eta 0:00:04
#    -------------------- ------------------- 6.8/13.3 MB 2.1 MB/s eta 0:00:04
#    --------------------- ------------------ 7.0/13.3 MB 2.1 MB/s eta 0:00:04
#    --------------------- ------------------ 7.1/13.3 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 7.3/13.3 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.4/13.3 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.5/13.3 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.7/13.3 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.8/13.3 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.8/13.3 MB 2.1 MB/s eta 0:00:03
#    ------------------------ --------------- 8.2/13.3 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 8.4/13.3 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 8.5/13.3 MB 2.2 MB/s eta 0:00:03
#    ------------------------- -------------- 8.5/13.3 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 9.1/13.3 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.3/13.3 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.4/13.3 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.5/13.3 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.6/13.3 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.7/13.3 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.7/13.3 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.7/13.3 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 10.3/13.3 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 10.3/13.3 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 10.4/13.3 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 10.5/13.3 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.7/13.3 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 10.9/13.3 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 11.0/13.3 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 11.1/13.3 MB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 11.2/13.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.3/13.3 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.7/13.3 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 12.1/13.3 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 12.2/13.3 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 12.7/13.3 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 13.0/13.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 2.6 MB/s eta 0:00:00
# Downloading cmdstanpy-1.2.5-py3-none-any.whl (94 kB)
#    ---------------------------------------- 0.0/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------  92.2/94.5 kB ? eta -:--:--
#    ---------------------------------------- 94.5/94.5 kB 33.5 kB/s eta 0:00:00
# Downloading holidays-0.64-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------- ---------------------------- 0.3/1.2 MB 21.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.6/1.2 MB 7.7 MB/s eta 0:00:01
#    ------------------------------ --------- 0.9/1.2 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.9 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Installing collected packages: stanio, importlib-resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.5 holidays-0.64 importlib-resources-6.5.2 prophet-1.1.6 stanio-0.5.1
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from prophet import Prophet

# %%
one_pizza_prophet = pd.DataFrame({'ds': one_pizza.index, 'y': one_pizza.values})

one_pizza_prophet.head()
# Out:
#           ds     y
# 0 2015-01-01  11.0
# 1 2015-01-02   8.0
# 2 2015-01-03   7.0
# 3 2015-01-04   9.0
# 4 2015-01-05   2.0

# %%
# one_pizza_prophet.set_index('ds', inplace=True)

# split train and test
pr_train = one_pizza_prophet[:-7]
pr_test = one_pizza_prophet[-7:]

# %%
# fit model prophet
pr_model = Prophet()
pr_model.fit(pr_train)
# Out:
# 05:17:36 - cmdstanpy - INFO - Chain [1] start processing
# 05:17:39 - cmdstanpy - INFO - Chain [1] done processing

# %%
# forcast for one week
pr_future = pr_model.make_future_dataframe(periods=7, freq='D')
pr_forecast = pr_model.predict(pr_future)

# %%
# extract forecast values
pr_forecast_values = pr_forecast['yhat'][-len(pr_test):].values

# %%
# Evaluate the model
mae = mean_absolute_error(pr_test['y'], pr_forecast_values)
mse = mean_squared_error(pr_test['y'], pr_forecast_values)
rmse = np.sqrt(mse)

print(f'prophet MAE: {mae}')
print(f'prophet MSE: {mse}')
print(f'prophet RMSE: {rmse}')
# Out:
# prophet MAE: 2.7151476488524073
# prophet MSE: 8.634839269837057
# prophet RMSE: 2.9385097021852857

# %%
concat_prophet = pd.concat([pr_test, pr_forecast[['yhat']].iloc[-len(pr_test):]], axis=1)
concat_prophet.columns = ['date','Actual', 'Predicted']
concat_prophet.set_index('date', inplace=True)
concat_prophet
# Out:
#             Actual  Predicted
# date
# 2015-12-24     4.0   6.738988
# 2015-12-26     5.0   7.638909
# 2015-12-27     4.0   6.996037
# 2015-12-28     2.0   5.388384
# 2015-12-29     4.0   6.942247
# 2015-12-30     6.0   5.800222
# 2015-12-31    10.0   5.898309

# %%
# visualize forecast
concat_prophet.plot(figsize=(12, 6))
plt.xlabel('Order Date')
plt.ylabel('Quantity Sold')
plt.title('Actual vs. Predicted Quantity Sold for "The Barbecue Chicken Pizza"')
plt.show()
